# %%
import tensorflow as tf
import pandas as pd
import numpy as np

# %%
pitches = []

# %%
for year in range(15, 19):
    for month in range(3, 12):
        if (year == 17 and month == 5) or (year == 18 and month == 5):
            pitches = pd.read_csv("pitchdata_" + str(month) + "_" + str(15) + "_" + str(year) + ".csv")

#pitches = pd.read_csv("pitchdata_3_18.csv", )

# %%
pitches.head()
# Out:
#    PITCHNO    TM_DATE     TM_TIME  PAOFINNING  PITCHOFPA       PITCHER  \
# 0        1  3/29/2018  2:40:39 PM           1          1  Hamels, Cole
# 1        2  3/29/2018  2:40:53 PM           1          2  Hamels, Cole
# 2        3  3/29/2018  2:41:08 PM           1          3  Hamels, Cole
# 3        4  3/29/2018  2:41:52 PM           2          1  Hamels, Cole
# 4        5  3/29/2018  2:42:05 PM           2          2  Hamels, Cole
#
#    PITCHERID PITCHERTHROWS PITCHERTEAM            BATTER      ...       Y0  \
# 0     430935          Left         TEX  Springer, George      ...       50
# 1     430935          Left         TEX  Springer, George      ...       50
# 2     430935          Left         TEX  Springer, George      ...       50
# 3     430935          Left         TEX     Bregman, Alex      ...       50
# 4     430935          Left         TEX     Bregman, Alex      ...       50
#
#          Z0       VX0         VY0       VZ0        AX0        AY0        AZ0  \
# ...
